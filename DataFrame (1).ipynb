# %%
import pandas as pd
df = pd.read_csv('titanic1.csv')

# %%
testdf = df.head()
testdf
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#locating a row
testdf.loc[[3,2,1]]

#locating a row by default index
type(testdf.iloc[[2,3,3]])

#locating column
ps = testdf['Pclass']

# %%
ps = testdf['Pclass']

#operation on series
ps

#count of elements
ps.value_counts()
ps.max()

#diffrent unique value
ps.unique()

ps.sort_values(ascending = False)

ps[ps > 1]
filter_series

filter_series.apply(lambda x: x**2)

#slicing element of series, its actually printing from 0 to 3
ps[:3]
a = 9
a
# Out:
# 9

# %%
#Working with the eq

#filtering row, you can use 2d type of the function of the value without the system
df[df['Age'] < 18][['Name', 'Fare','Sex']]

#fintering with the equation
temp = df[df['Age'] < 18][['Name', 'Fare','Sex']]
temp['Fare_INR'] = df['Fare'].apply(lambda x: x*80)
temp.head()

#fitering passenger with survived and age < 10
survKids = df[(df['Survived'] == 1) & (df['Age'] < 10)]
survKids

#fitering passenger with survived and age < 10 and sex = female
servGirls = df[(df['Survived'] == 1) & (df['Age'] < 10) & ( df['Sex'] == 'Female' )]
servGirls
survKids
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 43            44         1       2
# 58            59         1       2
# 78            79         1       2
# 165          166         1       3
# 172          173         1       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 381          382         1       3
# 407          408         1       2
# 445          446         1       1
# 448          449         1       3
# 469          470         1       3
# 479          480         1       3
# 489          490         1       3
# 530          531         1       2
# 535          536         1       2
# 549          550         1       2
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
