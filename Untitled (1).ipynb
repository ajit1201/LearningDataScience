# %%
import pandas as pd
import lxml

# %%
table = pd.read_html('https://www.pw.live/exams/gate/gate-cse-syllabus', flavor = 'lxml')

# %%
table
# Out:
# [                                 0                                   1
#  0  GATE Branch Wise Syllabus Links     GATE Branch Wise Syllabus Links
#  1           GATE ECE Syllabus 2024               GATE EE Syllabus 2024
#  2            GATE ME Syllabus 2024  GATE Instrumentation Syllabus 2024
#  3           GATE CSE Syllabus 2024            GATE Civil Syllabus 2024,
#                                               0  \
#  0  GATE CSE Syllabus 2024 For General Aptitude
#  1                                       Topics
#  2                              Verbal Aptitude
#  3                        Quantitative Aptitude
#  4                          Analytical Aptitude
#  5                             Spatial Aptitude
#
#                                                     1
#  0        GATE CSE Syllabus 2024 For General Aptitude
#  1                                         Sub-topics
#  2  English grammar Vocabularies Reading and compr...
# ...
